# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the Jupyter Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Write your Algorithm
# * [Step 6](#step6): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# Make sure that you've downloaded the required human and dog datasets:
#
# **Note: if you are using the Udacity workspace, you *DO NOT* need to re-download these - they can be found in the `/data` folder as noted in the cell below.**
#
# * Download the [dog dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip).  Unzip the folder and place it in this project's home directory, at the location `/dog_images`.
#
# * Download the [human dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip).  Unzip the folder and place it in the home directory, at location `/lfw`.
#
# *Note: If you are using a Windows machine, you are encouraged to use [7zip](http://www.7-zip.org/) to extract the folder.*
#
# In the code cell below, we save the file paths for both the human (LFW) dataset and dog dataset in the numpy arrays `human_files` and `dog_files`.

# %%
import numpy as np
from glob import glob

# load filenames for human and dog images
human_files = np.array(glob("/data/lfw/*/*"))
dog_files = np.array(glob("/data/dog_images/*/*/*"))

# print number of images in each dataset
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13233 total human images.
# There are 8351 total dog images.

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# In this section, we use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.
#
# OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.  In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[0])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.

# %% [markdown]
# __Answer:__
# (You can print out your results and/or write your percentages in this cell)

# %%
from tqdm import tqdm

human_files_short = human_files[:100]
dog_files_short = dog_files[:100]

#-#-# Do NOT modify the code above this line. #-#-#

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
n1, n2 = 0, 0
for img in human_files_short:
    if face_detector(img): n1 += 1

for img in dog_files_short:
    if face_detector(img): n2 += 1

print("Percentage of human images with detected human face: {}%".format(n1))
print("Percentage of dog images with detected human face: {}%".format(n2))
# Out:
# Percentage of human images with detected human face: 98%
# Percentage of dog images with detected human face: 17%

# %% [markdown]
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Test performance of anotherface detection algorithm.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html) to detect dogs in images.
#
# ### Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
import torch
import torchvision.models as models

# define VGG16 model
VGG16 = models.vgg16(pretrained=True)

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
if use_cuda:
    VGG16 = VGG16.cuda()

# %% [markdown]
# Given an image, this pre-trained VGG-16 model returns a prediction (derived from the 1000 possible categories in ImageNet) for the object that is contained in the image.

# %% [markdown]
# ### (IMPLEMENTATION) Making Predictions with a Pre-trained Model
#
# In the next code cell, you will write a function that accepts a path to an image (such as `'dogImages/train/001.Affenpinscher/Affenpinscher_00001.jpg'`) as input and returns the index corresponding to the ImageNet class that is predicted by the pre-trained VGG-16 model.  The output should always be an integer between 0 and 999, inclusive.
#
# Before writing the function, make sure that you take the time to learn  how to appropriately pre-process tensors for pre-trained models in the [PyTorch documentation](http://pytorch.org/docs/stable/torchvision/models.html).

# %%
from PIL import Image, ImageFile
import torchvision.transforms as transforms

ImageFile.LOAD_TRUNCATED_IMAGES = True

def VGG16_predict(img_path):
    '''
    Use pre-trained VGG-16 model to obtain index corresponding to 
    predicted ImageNet class for image at specified path
    
    Args:
        img_path: path to an image
        
    Returns:
        Index corresponding to VGG-16 model's prediction
    '''
    
    ## TODO: Complete the function.
    ## Load and pre-process an image from the given img_path
    
    transform = transforms.Compose([            
     transforms.Resize(256),                    
     transforms.CenterCrop(224),                
     transforms.ToTensor(),                     
     transforms.Normalize(                      
     mean=[0.485, 0.456, 0.406],                
     std=[0.229, 0.224, 0.225]                  
     )])
    
    img = Image.open(img_path)
    img_t = transform(img)
    batch_t = torch.unsqueeze(img_t, 0).to('cuda')
    
    ## Return the *index* of the predicted class for that image
    VGG16.eval()
    pred = VGG16(batch_t)
    
    return pred.argmax() # predicted class index

# %% [markdown]
# ### (IMPLEMENTATION) Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained VGG-16 model, we need only check if the pre-trained model predicts an index between 151 and 268 (inclusive).
#
# Use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    ## TODO: Complete the function.
    cat = VGG16_predict(img_path)
    return cat >= 151 and cat <= 268 # true/false

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 2:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?

# %% [markdown]
# __Answer:__
#
# 0% images in human_files_short have a detected dog, and 100% in dog_files_short have a detected dog.

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

n1, n2 = 0, 0
for img in human_files_short:
    if dog_detector(img): n1 += 1

for img in dog_files_short:
    if dog_detector(img): n2 += 1

print("Percentage of human images with detected dog: {}%".format(n1))
print("Percentage of dog images with detected dog: {}%".format(n2))
# Out:
# Percentage of human images with detected dog: 0%
# Percentage of dog images with detected dog: 100%

# %% [markdown]
# We suggest VGG-16 as a potential network to detect dog images in your algorithm, but you are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).  Please use the code cell below to test other pre-trained PyTorch models.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Report the performance of another pre-trained network.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 10%.  In Step 4 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have trouble distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dog_images/train`, `dog_images/valid`, and `dog_images/test`, respectively).  You may find [this documentation on custom datasets](http://pytorch.org/docs/stable/torchvision/datasets.html) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
import os
from torchvision import datasets

### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transforms, and batch_sizes

dirs = ['/data/dog_images/train', '/data/dog_images/valid', '/data/dog_images/test']
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
batch = 50 
worker = 0

train_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder(dirs[0], transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
    ])),
    batch_size=batch, shuffle=True,
    num_workers=worker, pin_memory=True)

val_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder(dirs[1], transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
    ])),
    batch_size=batch, shuffle=True,
    num_workers=worker, pin_memory=True)

test_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder(dirs[2], transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
    ])),
    batch_size=batch, shuffle=True,
    num_workers=worker, pin_memory=True)

loaders_scratch = {'train': train_loader, 'valid': val_loader, 'test': test_loader}

# %%
classes = [str(i) for i in range(0,133)]

# helper function to un-normalize and display an image
def imshow(img):
    ma = np.amax(img)
    mi = np.amin(img)
    img = (img-mi)/(ma-mi)  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])
    #print(images[idx])
    #print(images[idx].shape)
    #print(np.amax(images[idx])) 
    #print(np.amin(images[idx]))

# %% [markdown]
# **Question 3:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**: <br>
# - I set the size of all images to be 224 by 224 and augmented the dataset by normalizing as well as ramdonly flipping images.

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  Use the template in the code cell below.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Net, self).__init__()
        ## Define layers of a CNN
        
        self.conv1 = nn.Conv2d(3, 32, 3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)

        self.pool = nn.MaxPool2d(2, 2)
        
        self.fc1 = nn.Linear(7*7*128, 500)
        self.fc2 = nn.Linear(500, 133) 
        
        self.dropout = nn.Dropout(0.3)
    
    def forward(self, x):
        ## Define forward behavior
        
        # [224x224x3] -> [112x112x32] -> [28x28x64] -> [7x7x128]
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        
        # flatten
        x = x.view(-1, 7*7*128)
        
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        
        x = self.dropout(x)
        x = self.fc2(x)
        return x

#-#-# You so NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_scratch = Net()
print(model_scratch)

# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=6272, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=133, bias=True)
#   (dropout): Dropout(p=0.3)
# )

# %% [markdown]
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# __Answer:__
# - First created 3 convolutional layers with 3x3 kernels to capture image features
# - Used max pooling layer to reduce image dimension in order to control the overall dimension due to the increasing output channel size in convolutional layers
# - Added a dropout layer with rate of 0.3 to reduce overfitting
# - Used ReLu as the activation function for all except the last layers
# - Added two fully connected layers at the end
# - The number of nodes in the last layer corresponds to the number of classes we are predicting

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and the optimizer as `optimizer_scratch` below.

# %%
import torch.optim as optim

### TODO: select loss function
criterion_scratch = nn.CrossEntropyLoss()

### TODO: select optimizer
optimizer_scratch = optim.SGD(model_scratch.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_scratch.pt'`.

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            optimizer.zero_grad() # clear the gradients of all optimized variables
            output = model(data) # forward pass: compute predicted outputs by passing inputs to the model
            loss = criterion(output, target) 
            loss.backward() # backward pass
            optimizer.step() # perform a single optimization step (parameter update)
            train_loss += ((1 / (batch_idx + 1)) * (loss.data - train_loss)) # update running training loss
            
        ######################    
        # validate the model #
        ######################
        correct = 0.
        total = 0.
        
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## update the average validation loss
            
            output = model(data) # forward pass: compute predicted outputs by passing inputs to the model
            loss = criterion(output, target) # calculate the loss
            valid_loss += ((1 / (batch_idx + 1)) * (loss.data - valid_loss)) # update running validation loss

            # print training/validation statistics 
            print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
                epoch, 
                train_loss,
                valid_loss
                ))
            
            pred = output.data.max(1, keepdim=True)[1]
            # compare predictions to true label
            correct = np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
            total = data.size(0)
            
            print('\nVal Accuracy: %2d%% (%2d/%2d)' % (
            100. * correct / total, correct, total))
        
        ## TODO: save the model if validation loss has decreased        
        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss
            
            
    # return trained model
    return model


# train the model
model_scratch = train(10, loaders_scratch, model_scratch, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'model_scratch.pt')

# load the model that got the best validation accuracy
model_scratch.load_state_dict(torch.load('model_scratch.pt'))
# Out:
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 4.039247
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 3.928611
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 3.872196
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 3.880200
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 3.920955
#
# Val Accuracy:  2% ( 1/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 3.913931
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 3.944415
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 3.966921
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 3.988350
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 3.999573
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 4.016680
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 4.018350
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 4.011437
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 4.027780
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 4.038985
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 4.049740
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 1 	Training Loss: 3.955889 	Validation Loss: 4.057061
#
# Val Accuracy:  0% ( 0/35)
# Validation loss decreased (inf --> 4.057061).  Saving model ...
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.085701
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.081805
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.001012
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.057222
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.042944
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 3.990002
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.028178
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.022605
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.019128
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.049309
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.035394
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.036829
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.021835
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.025193
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.004880
#
# Val Accuracy: 18% ( 9/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 4.005562
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 2 	Training Loss: 3.866193 	Validation Loss: 3.993524
#
# Val Accuracy:  8% ( 3/35)
# Validation loss decreased (4.057061 --> 3.993524).  Saving model ...
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 4.115711
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 4.055568
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 4.042001
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 3.974912
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 4.034546
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 4.015796
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 3.994729
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 3.983703
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 3.978809
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 3.979807
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 3.971377
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 3.999616
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 4.000476
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 3.983206
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 3.974026
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 3.980573
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 3 	Training Loss: 3.812019 	Validation Loss: 3.977801
#
# Val Accuracy:  8% ( 3/35)
# Validation loss decreased (3.993524 --> 3.977801).  Saving model ...
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 4.173044
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 4.023034
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 4.075120
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 4.027527
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 4.084565
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 4.074145
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 4.054227
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 4.045172
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 4.022935
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 4.009230
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 3.995689
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 3.992582
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 3.982326
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 3.967081
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 3.979075
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 3.971578
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 4 	Training Loss: 3.773898 	Validation Loss: 3.973192
#
# Val Accuracy:  8% ( 3/35)
# Validation loss decreased (3.977801 --> 3.973192).  Saving model ...
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 3.975775
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 4.000537
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 4.046632
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 4.065862
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 4.026972
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 4.041883
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 3.996035
#
# Val Accuracy: 18% ( 9/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 4.007227
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 4.017704
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 4.010462
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 3.992384
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 4.012781
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 4.011262
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 3.985230
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 3.969608
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 3.954850
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 5 	Training Loss: 3.736476 	Validation Loss: 3.955558
#
# Val Accuracy: 22% ( 8/35)
# Validation loss decreased (3.973192 --> 3.955558).  Saving model ...
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 3.935004
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 3.990469
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 4.011155
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 4.114306
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 4.099565
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 4.033772
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 4.000250
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 4.038068
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 4.007354
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 3.968376
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 3.960058
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 3.954162
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 3.967886
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 3.938050
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 3.946182
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 3.940363
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 6 	Training Loss: 3.698475 	Validation Loss: 3.926472
#
# Val Accuracy: 14% ( 5/35)
# Validation loss decreased (3.955558 --> 3.926472).  Saving model ...
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.803854
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.851236
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.816697
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.814808
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.853330
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.853975
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.887146
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.870016
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.825555
#
# Val Accuracy: 18% ( 9/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.844269
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.822909
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.839462
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.830342
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.855148
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.875622
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.885558
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 7 	Training Loss: 3.675754 	Validation Loss: 3.879903
#
# Val Accuracy: 11% ( 4/35)
# Validation loss decreased (3.926472 --> 3.879903).  Saving model ...
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.450242
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.644280
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.741099
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.715956
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.754410
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.811024
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.800134
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.811259
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.821322
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.831808
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.829490
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.831707
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.855680
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.850165
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.836060
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.886783
#
# Val Accuracy:  2% ( 1/50)
# Epoch: 8 	Training Loss: 3.654516 	Validation Loss: 3.908360
#
# Val Accuracy:  8% ( 3/35)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.940919
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.954362
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.905425
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.853276
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.908254
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.879242
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.866586
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.874621
#
# Val Accuracy:  6% ( 3/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.857326
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.844588
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.853124
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.839298
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.856946
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.863320
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.877673
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.875711
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 9 	Training Loss: 3.600313 	Validation Loss: 3.896227
#
# Val Accuracy: 11% ( 4/35)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 4.157768
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.976317
#
# Val Accuracy: 20% (10/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.861856
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.878879
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.901128
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.895198
#
# Val Accuracy:  4% ( 2/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.878989
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.886794
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.878969
#
# Val Accuracy: 16% ( 8/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.907748
#
# Val Accuracy:  8% ( 4/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.914944
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.932751
#
# Val Accuracy: 10% ( 5/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.897936
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.913110
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.908787
#
# Val Accuracy: 12% ( 6/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.876961
#
# Val Accuracy: 14% ( 7/50)
# Epoch: 10 	Training Loss: 3.591300 	Validation Loss: 3.869869
#
# Val Accuracy: 17% ( 6/35)
# Validation loss decreased (3.879903 --> 3.869869).  Saving model ...

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# %%
# call test function    
test(loaders_scratch, model_scratch, criterion_scratch, use_cuda)
# Out:
# Test Loss: 3.882542
#
#
# Test Accuracy: 10% (89/836)

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %%
## TODO: Specify data loaders
loaders_transfer = loaders_scratch.copy()

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify dog breed.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
import torchvision.models as models
import torch.nn as nn

## TODO: Specify model architecture 

# initialize model
model_transfer = VGG16

# print out the model structure
print(model_transfer)

# freeze training for all "features" layers
for param in model_transfer.features.parameters():
    param.requires_grad = False
    
# repace the last layer in the vgg classifier group of layers 
n_inputs = model_transfer.classifier[6].in_features

# new layers automatically have requires_grad = True
last_layer = nn.Linear(n_inputs, 133)

model_transfer.classifier[6] = last_layer

# check to see that your last layer produces the expected number of outputs
print(model_transfer.classifier[6].out_features)


if use_cuda:
    model_transfer = model_transfer.cuda()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )
# 133

# %% [markdown]
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__
# - Chose the VGG16 model as it's a classic model for image classification which we've covered in lectures
# - Froze the weights for all feature layers in VGG16
# - Replaced the last layer by a fully connected layer with 133 nodes (# classes)

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/master/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/master/optim.html).  Save the chosen loss function as `criterion_transfer`, and the optimizer as `optimizer_transfer` below.

# %%
criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = torch.optim.SGD(model_transfer.classifier.parameters(), lr=0.001)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            optimizer.zero_grad() # clear the gradients of all optimized variables
            output = model(data) # forward pass: compute predicted outputs by passing inputs to the model
            loss = criterion(output, target) 
            loss.backward() # backward pass
            optimizer.step() # perform a single optimization step (parameter update)
            train_loss += ((1 / (batch_idx + 1)) * (loss.data - train_loss)) # update running training loss
            
        ######################    
        # validate the model #
        ######################
        correct = 0.
        total = 0.
        
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## update the average validation loss
            
            output = model(data) # forward pass: compute predicted outputs by passing inputs to the model
            loss = criterion(output, target) # calculate the loss
            valid_loss += ((1 / (batch_idx + 1)) * (loss.data - valid_loss)) # update running validation loss
            print("valid_loss:"+str(valid_loss))
            # print training/validation statistics 
            print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
                epoch, 
                train_loss,
                valid_loss
                ))
            
            pred = output.data.max(1, keepdim=True)[1]
            # compare predictions to true label
            correct = np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
            total = data.size(0)
            
            print('\nVal Accuracy: %2d%% (%2d/%2d)' % (
            100. * correct / total, correct, total))
        
        ## TODO: save the model if validation loss has decreased        
        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss
            
            
    # return trained model
    return model

# %%
# train the model
n_epochs = 5
model_transfer = train(n_epochs, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')

# load the model that got the best validation accuracy (uncomment the line below)
model_transfer.load_state_dict(torch.load('model_transfer.pt'))
# Out:
# valid_loss:tensor(3.6473, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.647321
#
# Val Accuracy: 50% (25/50)
# valid_loss:tensor(3.8161, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.816067
#
# Val Accuracy: 38% (19/50)
# valid_loss:tensor(3.8459, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.845881
#
# Val Accuracy: 40% (20/50)
# valid_loss:tensor(3.9012, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.901222
#
# Val Accuracy: 36% (18/50)
# valid_loss:tensor(3.8920, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.891955
#
# Val Accuracy: 46% (23/50)
# valid_loss:tensor(3.8836, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.883560
#
# Val Accuracy: 40% (20/50)
# valid_loss:tensor(3.8786, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.878623
#
# Val Accuracy: 44% (22/50)
# valid_loss:tensor(3.8784, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.878371
#
# Val Accuracy: 42% (21/50)
# valid_loss:tensor(3.8719, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.871938
#
# Val Accuracy: 26% (13/50)
# valid_loss:tensor(3.8813, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.881277
#
# Val Accuracy: 42% (21/50)
# valid_loss:tensor(3.8718, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.871828
#
# Val Accuracy: 44% (22/50)
# valid_loss:tensor(3.8697, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.869656
#
# Val Accuracy: 34% (17/50)
# valid_loss:tensor(3.8749, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.874886
#
# Val Accuracy: 36% (18/50)
# valid_loss:tensor(3.8756, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.875580
#
# Val Accuracy: 38% (19/50)
# valid_loss:tensor(3.8774, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.877427
#
# Val Accuracy: 42% (21/50)
# valid_loss:tensor(3.8815, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.881461
#
# Val Accuracy: 40% (20/50)
# valid_loss:tensor(3.8764, device='cuda:0')
# Epoch: 1 	Training Loss: 4.580891 	Validation Loss: 3.876414
#
# Val Accuracy: 51% (18/35)
# Validation loss decreased (inf --> 3.876414).  Saving model ...
# valid_loss:tensor(2.5335, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.533528
#
# Val Accuracy: 66% (33/50)
# valid_loss:tensor(2.5422, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.542169
#
# Val Accuracy: 68% (34/50)
# valid_loss:tensor(2.5753, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.575317
#
# Val Accuracy: 66% (33/50)
# valid_loss:tensor(2.5938, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.593809
#
# Val Accuracy: 54% (27/50)
# valid_loss:tensor(2.6276, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.627647
#
# Val Accuracy: 60% (30/50)
# valid_loss:tensor(2.6366, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.636563
#
# Val Accuracy: 68% (34/50)
# valid_loss:tensor(2.6553, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.655308
#
# Val Accuracy: 54% (27/50)
# valid_loss:tensor(2.6915, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.691536
#
# Val Accuracy: 60% (30/50)
# valid_loss:tensor(2.6947, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.694721
#
# Val Accuracy: 52% (26/50)
# valid_loss:tensor(2.6948, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.694813
#
# Val Accuracy: 60% (30/50)
# valid_loss:tensor(2.6822, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.682165
#
# Val Accuracy: 56% (28/50)
# valid_loss:tensor(2.6784, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.678363
#
# Val Accuracy: 60% (30/50)
# valid_loss:tensor(2.6750, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.674971
#
# Val Accuracy: 54% (27/50)
# valid_loss:tensor(2.6809, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.680864
#
# Val Accuracy: 54% (27/50)
# valid_loss:tensor(2.6845, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.684459
#
# Val Accuracy: 58% (29/50)
# valid_loss:tensor(2.6759, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.675891
#
# Val Accuracy: 66% (33/50)
# valid_loss:tensor(2.6878, device='cuda:0')
# Epoch: 2 	Training Loss: 3.422872 	Validation Loss: 2.687797
#
# Val Accuracy: 42% (15/35)
# Validation loss decreased (3.876414 --> 2.687797).  Saving model ...
# valid_loss:tensor(1.9847, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.984726
#
# Val Accuracy: 60% (30/50)
# valid_loss:tensor(1.9430, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.943035
#
# Val Accuracy: 62% (31/50)
# valid_loss:tensor(1.9305, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.930518
#
# Val Accuracy: 58% (29/50)
# valid_loss:tensor(1.8867, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.886749
#
# Val Accuracy: 66% (33/50)
# valid_loss:tensor(1.8084, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.808433
#
# Val Accuracy: 76% (38/50)
# valid_loss:tensor(1.7422, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.742245
#
# Val Accuracy: 80% (40/50)
# valid_loss:tensor(1.6993, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.699295
#
# Val Accuracy: 74% (37/50)
# valid_loss:tensor(1.7099, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.709891
#
# Val Accuracy: 66% (33/50)
# valid_loss:tensor(1.7081, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.708107
#
# Val Accuracy: 72% (36/50)
# valid_loss:tensor(1.6943, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.694272
#
# Val Accuracy: 76% (38/50)
# valid_loss:tensor(1.7141, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.714086
#
# Val Accuracy: 66% (33/50)
# valid_loss:tensor(1.7280, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.728010
#
# Val Accuracy: 66% (33/50)
# valid_loss:tensor(1.7157, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.715697
#
# Val Accuracy: 66% (33/50)
# valid_loss:tensor(1.6961, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.696063
#
# Val Accuracy: 74% (37/50)
# valid_loss:tensor(1.6978, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.697761
#
# Val Accuracy: 70% (35/50)
# valid_loss:tensor(1.6797, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.679710
#
# Val Accuracy: 80% (40/50)
# valid_loss:tensor(1.6781, device='cuda:0')
# Epoch: 3 	Training Loss: 2.318068 	Validation Loss: 1.678139
#
# Val Accuracy: 71% (25/35)
# Validation loss decreased (2.687797 --> 1.678139).  Saving model ...
# valid_loss:tensor(1.1021, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.102075
#
# Val Accuracy: 78% (39/50)
# valid_loss:tensor(1.2064, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.206401
#
# Val Accuracy: 66% (33/50)
# valid_loss:tensor(1.1820, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.182031
#
# Val Accuracy: 74% (37/50)
# valid_loss:tensor(1.1961, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.196080
#
# Val Accuracy: 76% (38/50)
# valid_loss:tensor(1.1815, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.181479
#
# Val Accuracy: 76% (38/50)
# valid_loss:tensor(1.1526, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.152650
#
# Val Accuracy: 82% (41/50)
# valid_loss:tensor(1.1971, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.197081
#
# Val Accuracy: 62% (31/50)
# valid_loss:tensor(1.2059, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.205857
#
# Val Accuracy: 76% (38/50)
# valid_loss:tensor(1.1801, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.180053
#
# Val Accuracy: 76% (38/50)
# valid_loss:tensor(1.1462, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.146182
#
# Val Accuracy: 88% (44/50)
# valid_loss:tensor(1.1458, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.145844
#
# Val Accuracy: 80% (40/50)
# valid_loss:tensor(1.1428, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.142848
#
# Val Accuracy: 82% (41/50)
# valid_loss:tensor(1.1669, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.166944
#
# Val Accuracy: 66% (33/50)
# valid_loss:tensor(1.1697, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.169735
#
# Val Accuracy: 74% (37/50)
# valid_loss:tensor(1.1638, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.163758
#
# Val Accuracy: 86% (43/50)
# valid_loss:tensor(1.1539, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.153867
#
# Val Accuracy: 78% (39/50)
# valid_loss:tensor(1.1536, device='cuda:0')
# Epoch: 4 	Training Loss: 1.615219 	Validation Loss: 1.153600
#
# Val Accuracy: 74% (26/35)
# Validation loss decreased (1.678139 --> 1.153600).  Saving model ...
# valid_loss:tensor(0.8475, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.847455
#
# Val Accuracy: 82% (41/50)
# valid_loss:tensor(0.8435, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.843518
#
# Val Accuracy: 82% (41/50)
# valid_loss:tensor(0.8456, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.845642
#
# Val Accuracy: 78% (39/50)
# valid_loss:tensor(0.8607, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.860663
#
# Val Accuracy: 76% (38/50)
# valid_loss:tensor(0.8779, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.877854
#
# Val Accuracy: 80% (40/50)
# valid_loss:tensor(0.8496, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.849562
#
# Val Accuracy: 88% (44/50)
# valid_loss:tensor(0.8296, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.829645
#
# Val Accuracy: 86% (43/50)
# valid_loss:tensor(0.8391, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.839145
#
# Val Accuracy: 80% (40/50)
# valid_loss:tensor(0.8424, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.842384
#
# Val Accuracy: 78% (39/50)
# valid_loss:tensor(0.8592, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.859178
#
# Val Accuracy: 76% (38/50)
# valid_loss:tensor(0.8686, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.868586
#
# Val Accuracy: 78% (39/50)
# valid_loss:tensor(0.8718, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.871811
#
# Val Accuracy: 78% (39/50)
# valid_loss:tensor(0.8631, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.863079
#
# Val Accuracy: 84% (42/50)
# valid_loss:tensor(0.8735, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.873500
#
# Val Accuracy: 78% (39/50)
# valid_loss:tensor(0.8801, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.880150
#
# Val Accuracy: 76% (38/50)
# valid_loss:tensor(0.8838, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.883823
#
# Val Accuracy: 76% (38/50)
# valid_loss:tensor(0.9019, device='cuda:0')
# Epoch: 5 	Training Loss: 1.216016 	Validation Loss: 0.901857
#
# Val Accuracy: 71% (25/35)
# Validation loss decreased (1.153600 --> 0.901857).  Saving model ...

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)
# Out:
# Test Loss: 0.883521
#
#
# Test Accuracy: 80% (670/836)

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan hound`, etc) that is predicted by your model.

# %%
loaders_transfer['train'].dataset.classes[:10]
# Out:
# ['001.Affenpinscher',
#  '002.Afghan_hound',
#  '003.Airedale_terrier',
#  '004.Akita',
#  '005.Alaskan_malamute',
#  '006.American_eskimo_dog',
#  '007.American_foxhound',
#  '008.American_staffordshire_terrier',
#  '009.American_water_spaniel',
#  '010.Anatolian_shepherd_dog']

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = [item[4:].replace("_", " ") for item in loaders_transfer['train'].dataset.classes] 

def predict_breed_transfer(img_path):
    # load the image and return the predicted breed
    transform = transforms.Compose([            
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
     ])
    
    img = Image.open(img_path)
    img_t = transform(img)
    batch_t = torch.unsqueeze(img_t, 0).to('cuda')
    
    model_transfer.eval()
    pred = model_transfer(batch_t)
    
    return class_names[pred.argmax()]

# %%
img = cv2.imread(dog_files[0])
plt.imshow(img)

# %%
predict_breed_transfer(dog_files[0])
# Out:
# 'Bullmastiff'

# %%
dog_files[0]
# Out:
# '/data/dog_images/train/103.Mastiff/Mastiff_06833.jpg'

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `human_detector` functions developed above.  You are __required__ to use your CNN from Step 4 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

def run_app(img_path):
    ## handle cases for a human face, dog, and neither
    
    if dog_detector(img_path):
        pred = predict_breed_transfer(img_path)
        print("Hello, dog! You looks like a ... {}".format(pred))
    elif face_detector(img_path):
        pred = predict_breed_transfer(img_path)
        print("Hello, human! You look like a ... {}".format(pred))
    else:
        print("Error: no human or dog detected in this image!")

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that _you_ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement) <br>
# The output is not as good as I expected since it wasn't able to detect dogs in the last two images.
# Possible points for improvement: <br>
# 1) Use a more systematic method for hyperparameter tuning such as grid search <br>
# 2) Use more dog photos with different poses/angles (e.g. side view like the last dog image) for training <br>
# 3) Better image augmentation

# %%
human_pics = ['./my_images/trump.jpg', './my_images/obama.jpg', './my_images/elonmusk.jpg' ]
dog_pics = ['./my_images/corgi.jpg','./my_images/corgi2.jpg', './my_images/pomeranian.jpg']

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

## suggested code, below
for file in np.hstack((human_pics, dog_pics)):
    img = Image.open(file)
    plt.imshow(img)
    plt.show()
    
    run_app(file)
# Out:
# Hello, human! You look like a ... Irish water spaniel
# Hello, human! You look like a ... German pinscher
# Hello, human! You look like a ... Cardigan welsh corgi
# Hello, human! You look like a ... Pembroke welsh corgi
# Error: no human or dog detected in this image!
# Error: no human or dog detected in this image!
